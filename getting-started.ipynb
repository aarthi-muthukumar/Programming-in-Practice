# %% [markdown]
# # Getting Started with Jupyter Notebook and Python

# %% [markdown]
# ## Python
# Python is a programming language—essentially a way to give instructions to a computer.
#
# Why Python (especially for medical students)?
#
# - It reads almost like English
# - It’s widely used in biomedical research, data analysis, machine learning, and healthcare
#
# Many tools you’ll encounter later (statistics, imaging, AI) are built in Python. You don’t need to be a “computer person” to use Python. If you can think logically and follow steps, you can program.
#
# ## Jupyter Notebook
# This course is organized as a series of Jupyter Notebooks, like this file. Each notebook is made up of two main types of cells:
#
# 1. Code cells → where we write and run Python code
# 2. Markdown cells → where we write notes, explanations, and instructions in plain text
#
# This setup allows us to intersperse our code with explanations, just like a guided lab manual. You can run a code cell by pressing **Shift + Enter**.

# %%
# In a code block you'll often see a hashtag with notes afterwards. This is called a comment. Comments are notes for humans—they are ignored by the computer.

# %%
# Libraries
# Libraries are specialized packages that are made by different code developers to make your life easier. They come with pre-made functions that you can use, so that you don't have to code things from scratch
# in order to use a library, you have to write an import statement, like so: 

import numpy as np

# write "as" shows that you'll be referring to the Numpy package as "np" for the remainder of the file, kind of like an abbreviation
# here are a list of the most common Python packages that you will probbaly use in data analysis

import pandas as pd  # Used for working with tables of data (like Excel spreadsheets)
import matplotlib.pyplot as plt  # Used for creating graphs and visualizations
